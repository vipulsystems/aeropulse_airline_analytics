# %%
from pathlib import Path
import zipfile as zip
import numpy as np
import pandas as pd
import os

# %%
Path.cwd()

folders = [
    "01_Raw_Data",
    "02_Documentation",
    "03_Notebooks",
    "04_Cleaned_Data",
    "05_Analysis",
    "06_Visualization",
    "07_Business_Report"
]

for folder in folders:

    Path(folder).mkdir(parents=True, exist_ok=True)

# %%
file = "F:/DA_29 Python/aeropulse_airline_analytics/notebooks/01_Raw_Data/2024"
# Out:
# WindowsPath('.')
